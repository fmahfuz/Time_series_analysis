# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import json

# %%
  
# Opening JSON file
g=open('logins.json')
data=json.load(g)

# %%
data
# Out:
# {'login_time': ['1970-01-01 20:13:18',
#   '1970-01-01 20:16:10',
#   '1970-01-01 20:16:37',
#   '1970-01-01 20:16:36',
#   '1970-01-01 20:26:21',
#   '1970-01-01 20:21:41',
#   '1970-01-01 20:12:16',
#   '1970-01-01 20:35:47',
#   '1970-01-01 20:35:38',
#   '1970-01-01 20:47:52',
#   '1970-01-01 20:26:05',
#   '1970-01-01 20:31:03',
#   '1970-01-01 20:34:46',
#   '1970-01-01 20:36:34',
#   '1970-01-01 20:39:25',
#   '1970-01-01 20:40:37',
#   '1970-01-01 20:34:58',
#   '1970-01-01 20:43:59',
#   '1970-01-01 20:47:46',
#   '1970-01-01 20:46:34',
#   '1970-01-01 20:56:07',
#   '1970-01-01 20:49:12',
#   '1970-01-01 20:59:06',
#   '1970-01-01 20:59:59',
#   '1970-01-01 21:15:01',
#   '1970-01-01 21:09:24',
#   '1970-01-01 21:19:24',
#   '1970-01-01 21:20:53',
#   '1970-01-01 21:29:19',
#   '1970-01-01 21:58:05',
#   '1970-01-01 21:51:51',
#   '1970-01-01 21:59:40',
#   '1970-01-01 22:08:34',
#   '1970-01-01 22:02:51',
#   '1970-01-01 21:58:32',
#   '1970-01-01 22:02:31',
#   '1970-01-01 22:05:32',
#   '1970-01-01 22:02:46',
#   '1970-01-01 22:10:28',
#   '1970-01-01 22:11:58',
#   '1970-01-01 22:01:05',
#   '1970-01-01 22:19:10',
#   '1970-01-01 22:16:54',
#   '1970-01-01 22:17:32',
#   '1970-01-01 22:12:05',
#   '1970-01-01 22:23:03',
#   '1970-01-01 22:22:14',
#   '1970-01-01 22:25:09',
#   '1970-01-01 22:24:04',
#   '1970-01-01 22:19:59',
#   '1970-01-01 22:31:32',
#   '1970-01-01 23:06:11',
#   '1970-01-01 22:55:56',
#   '1970-01-01 23:07:09',
#   '1970-01-01 23:11:56',
#   '1970-01-01 23:04:35',
#   '1970-01-01 23:04:28',
#   '1970-01-01 23:12:51',
#   '1970-01-01 23:08:05',
#   '1970-01-01 23:11:37',
#   '1970-01-01 23:09:31',
#   '1970-01-01 22:57:55',
#   '1970-01-01 23:14:00',
#   '1970-01-01 23:09:06',
#   '1970-01-01 23:07:31',
#   '1970-01-01 23:09:13',
#   '1970-01-01 22:56:25',
#   '1970-01-01 23:09:55',
#   '1970-01-01 23:18:34',
#   '1970-01-01 23:09:22',
#   '1970-01-01 23:21:30',
#   '1970-01-01 23:07:45',
#   '1970-01-01 23:23:25',
#   '1970-01-01 23:16:11',
#   '1970-01-01 23:22:05',
#   '1970-01-01 23:17:48',
#   '1970-01-01 23:24:13',
#   '1970-01-01 23:25:52',
#   '1970-01-01 23:33:36',
#   '1970-01-01 23:31:00',
#   '1970-01-01 23:20:43',
#   '1970-01-01 23:26:11',
#   '1970-01-01 23:21:06',
#   '1970-01-01 23:26:59',
#   '1970-01-01 23:30:37',
#   '1970-01-01 23:38:24',
#   '1970-01-01 23:38:05',
#   '1970-01-01 23:33:54',
#   '1970-01-01 23:30:32',
#   '1970-01-01 23:45:41',
#   '1970-01-03 02:32:29',
#   '1970-01-03 02:33:59',
#   '1970-01-03 02:34:04',
#   '1970-01-03 02:31:39',
#   '1970-01-03 02:32:20',
#   '1970-01-03 02:38:44',
#   '1970-01-03 02:31:20',
#   '1970-01-03 02:37:04',
#   '1970-01-03 02:27:52',
#   '1970-01-03 02:31:41',
#   '1970-01-03 02:38:17',
#   '1970-01-03 02:41:33',
#   '1970-01-03 02:28:51',
#   '1970-01-03 02:29:48',
#   '1970-01-03 02:42:24',
#   '1970-01-03 02:44:21',
#   '1970-01-03 02:49:17',
#   '1970-01-03 02:35:52',
#   '1970-01-03 02:42:58',
#   '1970-01-03 02:51:56',
#   '1970-01-03 02:50:14',
#   '1970-01-03 02:47:54',
#   '1970-01-03 02:46:39',
#   '1970-01-03 02:52:48',
#   '1970-01-03 02:50:13',
#   '1970-01-03 02:53:20',
#   '1970-01-03 03:00:16',
#   '1970-01-03 02:57:30',
#   '1970-01-03 02:59:11',
#   '1970-01-03 02:54:07',
#   '1970-01-03 03:08:43',
#   '1970-01-03 03:08:16',
#   '1970-01-03 03:14:03',
#   '1970-01-03 03:03:07',
#   '1970-01-03 03:03:01',
#   '1970-01-03 03:05:08',
#   '1970-01-03 03:15:33',
#   '1970-01-03 03:08:24',
#   '1970-01-03 03:08:56',
#   '1970-01-03 03:05:42',
#   '1970-01-03 03:10:09',
#   '1970-01-03 03:17:10',
#   '1970-01-03 03:03:13',
#   '1970-01-03 03:09:43',
#   '1970-01-03 03:02:05',
#   '1970-01-03 03:18:14',
#   '1970-01-03 03:11:03',
#   '1970-01-03 03:15:16',
#   '1970-01-03 03:08:14',
#   '1970-01-03 03:09:47',
#   '1970-01-03 03:12:01',
#   '1970-01-03 03:25:17',
#   '1970-01-03 03:12:33',
#   '1970-01-03 03:14:58',
#   '1970-01-03 03:17:48',
#   '1970-01-03 03:20:27',
#   '1970-01-03 03:17:51',
#   '1970-01-03 03:21:19',
#   '1970-01-03 03:19:51',
#   '1970-01-03 03:26:38',
#   '1970-01-03 03:20:37',
#   '1970-01-03 03:05:38',
#   '1970-01-03 03:18:02',
#   '1970-01-03 03:18:25',
#   '1970-01-03 03:23:59',
#   '1970-01-03 03:25:16',
#   '1970-01-03 03:25:39',
#   '1970-01-03 03:27:47',
#   '1970-01-03 03:28:47',
#   '1970-01-03 03:21:37',
#   '1970-01-03 03:20:56',
#   '1970-01-03 03:26:28',
#   '1970-01-03 03:33:23',
#   ...]}

# %%
df = pd.read_json('logins.json')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   login_time  93142 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 727.8 KB

# %%
df_logins = pd.DataFrame(pd.to_datetime(df['login_time']),columns=['login_time'])

# %%
df_logins.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
df['logins']=1
df.set_index('login_time')
# Out:
#                      logins
# login_time
# 1970-01-01 20:13:18       1
# 1970-01-01 20:16:10       1
# 1970-01-01 20:16:37       1
# 1970-01-01 20:16:36       1
# 1970-01-01 20:26:21       1
# ...                     ...
# 1970-04-13 18:50:19       1
# 1970-04-13 18:43:56       1
# 1970-04-13 18:54:02       1
# 1970-04-13 18:57:38       1
# 1970-04-13 18:54:23       1
#
# [93142 rows x 1 columns]

# %%
#df_grouped=pd.DataFrame(df.groupby([pd.Grouper(key='', freq='15Min')]).sum()).reset_index()
df_grouped=df.groupby(pd.Grouper(key="login_time", freq="15Min")).sum()

# %%
df_grouped
# Out:
#                      logins
# login_time
# 1970-01-01 20:00:00       2
# 1970-01-01 20:15:00       6
# 1970-01-01 20:30:00       9
# 1970-01-01 20:45:00       7
# 1970-01-01 21:00:00       1
# ...                     ...
# 1970-04-13 17:45:00       5
# 1970-04-13 18:00:00       5
# 1970-04-13 18:15:00       2
# 1970-04-13 18:30:00       7
# 1970-04-13 18:45:00       6
#
# [9788 rows x 1 columns]

# %%
df_grouped.head()
# Out:
#                     idx  logins
# idx
# 0   1970-01-01 20:00:00       2
# 1   1970-01-01 20:15:00       6
# 2   1970-01-01 20:30:00       9
# 3   1970-01-01 20:45:00       7
# 4   1970-01-01 21:00:00       1

# %%
plt.figure(figsize=(18,6))
plt.plot(df_grouped)

# %%
#create new columns for items of interest
df_count = df_grouped.assign(month_day=df_grouped.index.day)
df_count = df_count.assign(weekday=df_grouped.index.weekday)
df_count.head()
# Out:
#                      logins  month_day  weekday
# login_time
# 1970-01-01 20:00:00       2          1        3
# 1970-01-01 20:15:00       6          1        3
# 1970-01-01 20:30:00       9          1        3
# 1970-01-01 20:45:00       7          1        3
# 1970-01-01 21:00:00       1          1        3

# %%
spike = np.quantile(df_count,0.99)
df_spike = df_count[df_count['logins'] >= spike]
month_days = []
weekdays = []
for date in df_spike.index:
    month_days.append(date.day)
    weekdays.append(date.weekday())
    
df_spike_days = pd.DataFrame(month_days,columns=['day'],index=range(len(month_days)))
df_spike_weekdays = pd.DataFrame(weekdays,columns=['weekday'],index=range(len(weekdays)))

# %%
df_spike_days.day.value_counts()[0:10]
# Out:
# 21    25
# 4     24
# 22    18
# 15    18
# 28    17
# 7     15
# 8     15
# 14    14
# 29    14
# 3     13
# Name: day, dtype: int64

# %%
df_spike_weekdays.weekday.value_counts()
# Out:
# 5    104
# 6    103
# 4     48
# 3     15
# 2      7
# 1      7
# 0      2
# Name: weekday, dtype: int64

# %%
#resample to daily frequency
df_day = df_count['logins'].resample('1D').sum()
df_day.plot(kind='line',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
#import data from json file
file = 'ultimate_data_challenge.json'
with open(file) as f:
    data = json.loads(f.read())
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
# 5      Winterfell                       2  2014-01-09                   3.5
# 6         Astapor                       1  2014-01-24                   NaN
# 7      Winterfell                       2  2014-01-28                   5.0
# 8      Winterfell                       2  2014-01-21                   4.5
# 9      Winterfell                       1  2014-01-03                   NaN
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
# 5       1.00     2014-06-06   iPhone        0.0                 True
# 6       1.00     2014-01-25  Android        0.0                False
# 7       1.00     2014-01-29   iPhone        0.0                False
# 8       1.00     2014-02-01  Android        0.0                False
# 9       1.00     2014-01-05  Android        0.0                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# 0         46.2      3.67                   5.0
# 1         50.0      8.26                   5.0
# 2        100.0      0.77                   5.0
# 3         80.0      2.36                   4.9
# 4         82.4      3.13                   4.9
# 5        100.0     10.56                   5.0
# 6        100.0      3.95                   4.0
# 7        100.0      2.04                   5.0
# 8        100.0      4.36                   5.0
# 9          0.0      2.37                   5.0

# %%
#break down trip counts by percentage
df_tripcounts = df['trips_in_first_30_days'].value_counts(normalize=True)*100
df_tripcounts.head(7)
# Out:
# 0    30.780
# 1    28.216
# 2    14.804
# 3     7.576
# 4     5.124
# 5     3.232
# 6     2.268
# Name: trips_in_first_30_days, dtype: float64

# %%
np.sum(df_tripcounts[1:])
# Out:
# 69.22

# %%
#drop rows with no phone information, since we cannot infer that without building a predictive model
df = df.drop(df[df.phone.isna()==True].index,axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49604 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    49604 non-null  object
#  1   trips_in_first_30_days  49604 non-null  int64
#  2   signup_date             49604 non-null  object
#  3   avg_rating_of_driver    41578 non-null  float64
#  4   avg_surge               49604 non-null  float64
#  5   last_trip_date          49604 non-null  object
#  6   phone                   49604 non-null  object
#  7   surge_pct               49604 non-null  float64
#  8   ultimate_black_user     49604 non-null  bool
#  9   weekday_pct             49604 non-null  float64
#  10  avg_dist                49604 non-null  float64
#  11  avg_rating_by_driver    49406 non-null  float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.6+ MB

# %%
df['avg_rating_by_driver'].describe()
# Out:
# count    49406.000000
# mean         4.777861
# std          0.447114
# min          1.000000
# 25%          4.700000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: avg_rating_by_driver, dtype: float64

# %%
df['avg_rating_of_driver'].describe()
# Out:
# count    41578.000000
# mean         4.601467
# std          0.617377
# min          1.000000
# 25%          4.300000
# 50%          4.900000
# 75%          5.000000
# max          5.000000
# Name: avg_rating_of_driver, dtype: float64

# %%
#fill missing values by averaging the mean and median
fill_val = (4.777861+5) / 2
df['avg_rating_by_driver'] = df['avg_rating_by_driver'].fillna(value=fill_val)

#fill missing values with median value
df['avg_rating_of_driver'] = df['avg_rating_of_driver'].fillna(value=4.9)

# %%
#convert to timestamp
df['last_trip_date'] = pd.to_datetime(df['last_trip_date'])

# %%
#set current date 
current_date = df['last_trip_date'].max()

# %%
#find if user qualifies as active
df['active'] = df['last_trip_date'].apply(lambda date: 0 if (current_date-date).days>30 else 1)
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver  active
# 0         46.2      3.67                   5.0       1
# 1         50.0      8.26                   5.0       0
# 2        100.0      0.77                   5.0       0
# 3         80.0      2.36                   4.9       1
# 4         82.4      3.13                   4.9       0

# %%
#create dummy variables for categorical features
df_features = pd.get_dummies(df,columns=['city','phone','ultimate_black_user'])
df_features.head()
#set target and drop unuseful columns
target = df_features['active']
df_features = df_features.drop(['last_trip_date','signup_date','active'],axis=1)

# %%
df.active.value_counts(normalize=True)*100
# Out:
# 0    62.35989
# 1    37.64011
# Name: active, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
#scale data
scaler = QuantileTransformer()
scaled_features = scaler.fit_transform(df_features)

# %%
#split data for training and testing
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2,random_state=42)

# %%
#build random forest model with 1000 estimators
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)

# %%
rf.score(X_test,y_test)
# Out:
# 0.7492188287471021

# %%
print(cross_val_score(rf,X_test,np.ravel(y_test),cv=5))
print('Mean Cross Validated Score:',np.mean(cross_val_score(rf,X_test,np.ravel(y_test),cv=5)))
# Out:
# [0.75566751 0.74899194 0.7484879  0.74546371 0.74395161]
# Mean Cross Validated Score: 0.7500247826440238

# %%
df_importance = pd.DataFrame(zip(list(df_features.columns),rf.feature_importances_),index=range(df_features.columns.shape[0]),columns=['feature','importance'])
df_importance.sort_values(by='importance',ascending=False)
# Out:
#                       feature  importance
# 5                    avg_dist    0.300832
# 4                 weekday_pct    0.132992
# 6        avg_rating_by_driver    0.112209
# 0      trips_in_first_30_days    0.081144
# 1        avg_rating_of_driver    0.080811
# 3                   surge_pct    0.079988
# 2                   avg_surge    0.065624
# 8         city_King's Landing    0.047269
# 11               phone_iPhone    0.020331
# 10              phone_Android    0.019280
# 13   ultimate_black_user_True    0.016625
# 12  ultimate_black_user_False    0.016506
# 7                city_Astapor    0.015606
# 9             city_Winterfell    0.010785

# %%
#more metrics for our model
precision_recall_fscore_support(y_test,y_pred)
# Out:
# (array([0.79964482, 0.66541454]),
#  array([0.79887097, 0.6664875 ]),
#  array([0.79925771, 0.66595059]),
#  array([6200, 3721]))

# %%
#weighted metrics
precision_recall_fscore_support(y_test,y_pred,average='weighted')
# Out:
# (0.7493000082300401, 0.7492188287471021, 0.7492591393351211, None)

# %%
#generate confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[4953, 1247],
#        [1241, 2480]])
